# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

# %%
(X_train,y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 60000
# 10000

# %%
plt.matshow(X_train[0])
plt.show()

# %%
X_train[0].shape
# Out:
# (28, 28)

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
X_train_flat = X_train.reshape(len(X_train), 28*28)

# %%
X_test_flat = X_test.reshape(len(X_test), 28*28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
X_train_flat = X_train_flat / 255
X_test_flat = X_test_flat / 255

# %%
model = keras.Sequential([
    keras.layers.Dense(10, input_shape=(784,), activation='sigmoid')    
])
model.compile(
              optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy',
              metrics = 'accuracy'
    
)
model.fit(X_train_flat, y_train, epochs = 5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6874 - accuracy: 0.8253
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3053 - accuracy: 0.9145
# Epoch 3/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.2818 - accuracy: 0.9186
# Epoch 4/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2728 - accuracy: 0.9225
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2621 - accuracy: 0.9271

# %%
model.evaluate(X_test_flat, y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.2711 - accuracy: 0.9247
# [0.2711246609687805, 0.9247000217437744]

# %%
y_pred = model.predict(X_test_flat)

# %%
import numpy as np
np.argmax(y_pred[1])
# Out:
# 2

# %%
y_test[1]
# Out:
# 2

# %%
y_pred_labels = [np.argmax(i) for i in y_pred]

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
sns.heatmap(tf.math.confusion_matrix(y_test, y_pred_labels), annot=True)
plt.show()

# %%
model = keras.Sequential([
    keras.layers.Dense(100, input_shape = (784,), activation = 'relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

model.compile(    
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics='accuracy'
)
model.fit(X_train_flat, y_train, epochs = 5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4551 - accuracy: 0.8703
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1336 - accuracy: 0.9620
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0878 - accuracy: 0.9734
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0679 - accuracy: 0.9788
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0506 - accuracy: 0.9843

# %%
y_pred = model.predict(X_test_flat)
y_pred_labels = [np.argmax(i) for i in y_pred]

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
sns.heatmap(tf.math.confusion_matrix(y_test, y_pred_labels), annot=True)
plt.show()

# %%
X_train = X_train/255
X_test = X_test/255

model = keras.Sequential([
    keras.layers.Flatten(input_shape= (28,28)),
    keras.layers.Dense(100, activation = 'relu'),
    keras.layers.Dense(10, activation='sigmoid')
])

model.compile(    
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics='accuracy'
)
model.fit(X_train, y_train, epochs = 5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4551 - accuracy: 0.8722
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1287 - accuracy: 0.9618
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0868 - accuracy: 0.9742
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0621 - accuracy: 0.9811
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0498 - accuracy: 0.9845

# %%
y_pred = model.predict(X_test)
y_pred_labels = [np.argmax(i) for i in y_pred]

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
sns.heatmap(tf.math.confusion_matrix(y_test, y_pred_labels), annot=True)
plt.show()

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(100, activation = 'relu'),
    keras.layers.Dense(10, activation='sigmoid')    
])
model.compile(
    optimizer = keras.optimizers.Adam(),
    loss = keras.losses.sparse_categorical_crossentropy,
    metrics = ['accuracy','mean_absolute_error']
)
model.fit(X_train, y_train, epochs = 5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4571 - accuracy: 0.8711 - mean_absolute_error: 4.0793
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1289 - accuracy: 0.9635 - mean_absolute_error: 4.1541
# Epoch 3/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0839 - accuracy: 0.9752 - mean_absolute_error: 4.2114
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0667 - accuracy: 0.9801 - mean_absolute_error: 4.2157
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0509 - accuracy: 0.9844 - mean_absolute_error: 4.2218

# %%
y_pred = model.predict(X_test)
y_pred_labels = [np.argmax(i) for i in y_pred]

# %%
import seaborn as sns
plt.figure(figsize=(10,5))
sns.heatmap(tf.math.confusion_matrix(y_test, y_pred_labels), annot=True, cmap='YlGnBu')
plt.show()
